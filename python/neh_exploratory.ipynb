# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data/NEH_Grants.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63734 entries, 0 to 63733
# Data columns (total 32 columns):
# Unnamed: 0           63734 non-null int64
# AppNumber            63734 non-null object
# ApplicantType        63734 non-null object
# ApprovedMatching     63734 non-null float64
# ApprovedOutright     63734 non-null float64
# AwardMatching        63734 non-null float64
# AwardOutright        63734 non-null float64
# BeginGrant           63734 non-null object
# CouncilDate          63734 non-null object
# Discipline           63662 non-null object
# DisciplineCount      63734 non-null int64
# Division             63734 non-null object
# EndGrant             63734 non-null object
# InstCity             63734 non-null object
# InstCountry          63734 non-null object
# InstPostalCode       63734 non-null object
# InstState            63734 non-null object
# Institution          63734 non-null object
# OrganizationType     63734 non-null object
# ...

# %%
df['ProjectDesc'].str.match('{}').sum()
# Out:
# 49601

# %%
df['ProjectDesc'].count()
# Out:
# 63733

# %%
df['ToSupport'].str.match('{}').sum()
# Out:
# 37632

# %%
df['ToSupport'].count()
# Out:
# 63734

# %%
#Finding which values are missing in both
(df['ProjectDesc'].str.match('{}') & df['ToSupport'].str.match('{}')).sum()
# Out:
# 27160

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'AppNumber', 'ApplicantType', 'ApprovedMatching',
#        'ApprovedOutright', 'AwardMatching', 'AwardOutright', 'BeginGrant',
#        'CouncilDate', 'Discipline', 'DisciplineCount', 'Division', 'EndGrant',
#        'InstCity', 'InstCountry', 'InstPostalCode', 'InstState', 'Institution',
#        'OrganizationType', 'OriginalAmount', 'Participant', 'ParticipantCount',
#        'PrimaryDiscipline', 'Program', 'ProjectDesc', 'ProjectTitle',
#        'Supplement', 'SupplementAmount', 'SupplementCount', 'ToSupport',
#        'Unnamed: 0.1', 'YearAwarded'],
#       dtype='object')

# %%
info = ['AppNumber','Institution', 'ProjectTitle', "YearAwarded", "AwardOutright", "AwardMatching"]
df[df["AwardOutright"]<0][info]
# Out:
#          AppNumber                       Institution  \
# 27061  RE-20024-82            University of Virginia
# 27851  RO-20587-84  Unaffiliated Independent Scholar
# 28244  RP-20529-84        Princeton University Press
#
#                                             ProjectTitle  YearAwarded  \
# 27061                    The Papers of George Washington         1981
# 27851                               Ancient Maya Writing         1984
# 28244  Purchase of Penta Tele/Media Interface for Tra...         1984
#
#        AwardOutright  AwardMatching
# 27061         -69.92       135000.0
# 27851         -40.03        16070.0
# 28244       -1041.77        11748.0

# %%
info = ['AppNumber','Institution', 'ProjectTitle', "YearAwarded", "AwardOutright", "AwardMatching"]
df[df["AwardMatching"]<0][info]
# Out:
#          AppNumber                       Institution  \
# 24428  GL-20553-84  South Dakota Library Association
#
#                                        ProjectTitle  YearAwarded  \
# 24428  South Dakota: Changing, Changeless 1889-1989         1984
#
#        AwardOutright  AwardMatching
# 24428      193509.22       -7794.01

# %%
df[(df["AwardOutright"]==0) & (df["AwardMatching"]==0)][info].to_csv("no_funding.csv")

# %%
df[df['BeginGrant'].str.contains("9999-09-01")][info]
# Out:
#        AppNumber                               Institution  \
# 237  FB-20271-67                 University of Connecticut
# 689  FB-20273-66                       Wesleyan University
# 690  FB-20275-67                           Yale University
# 691  FB-20277-67  Trinity University, District of Columbia
#
#             ProjectTitle  YearAwarded  AwardOutright  AwardMatching
# 237  Title not available         1967         8140.0            0.0
# 689  Title not available         1966         8140.0            0.0
# 690  Title not available         1967         8140.0            0.0
# 691  Title not available         1967         8140.0            0.0

# %%
df[info].sort(columns="AwardOutright")
# Out:
# /Users/hannah/anaconda/envs/neh/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           AppNumber                                        Institution  \
# 28244   RP-20529-84                         Princeton University Press
# 27061   RE-20024-82                             University of Virginia
# 27851   RO-20587-84                   Unaffiliated Independent Scholar
# 31649   FE-21891-88         Pennsylvania State University - Brandywine
# 15179  PD-092776-79              Massachusetts Institute of Technology
# 40014   FE-25382-91                             Harvard Semitic Museum
# 49095   RZ-20967-02                            Northwestern University
# 49102   CH-20625-00                           Alabama State University
# 49103   CH-20626-00                       American Antiquarian Society
# 49104   CH-20627-00              American Council of Learned Societies
# ...

# %%
df.ix[46402][["ApprovedOutright", "ApprovedMatching","AwardOutright", "AwardMatching",
              'Supplement', 'SupplementAmount', 'SupplementCount', 'OriginalAmount','BeginGrant']]
# Out:
# ApprovedOutright                                          4.18077e+06
# ApprovedMatching                                                    0
# AwardOutright                                             4.18077e+06
# AwardMatching                                                       0
# Supplement          [{'SupplementDate': '1994-06-24T00:00:00', 'Ou...
# SupplementAmount                                          2.77844e+06
# SupplementCount                                                     3
# OriginalAmount                                            1.40232e+06
# BeginGrant                                        1991-10-01T00:00:00
# Name: 46402, dtype: object

# %%
df.ix[46402]['Supplement']
# Out:
# "[{'SupplementDate': '1994-06-24T00:00:00', 'OutrightAmount': '929345.0000', 'MatchAmount': '0.0000'}, {'SupplementDate': '1996-05-13T00:00:00', 'OutrightAmount': '1000000.0000', 'MatchAmount': '0.0000'}, {'SupplementDate': '1998-05-27T00:00:00', 'OutrightAmount': '849100.0000', 'MatchAmount': '0.0000'}]"

# %%
929345+1000000+849100
# Out:
# 2778445

# %%
4.18077e+06 - 2778445
# Out:
# 1402325.0
