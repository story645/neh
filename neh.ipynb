# %%
import glob
import os
import pandas as pd

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import shapely.geometry as sgeom
import matplotlib.colors as mcolors
import matplotlib.cm as mcm
import matplotlib.ticker as mticker

import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader

# %%
dfs = []
for fn in glob.glob('NEH_CSV/*.csv'):
    dfs.append(pd.read_csv(fn))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)

# %%
import numpy as np
np.log10(740060692)
# Out:
# 8.86926733746051

# %%
big_frame.keys()
# Out:
# Index(['AppNumber', 'ApplicantType', 'ApprovedMatching', 'ApprovedOutright',
#        'AwardMatching', 'AwardOutright', 'BeginGrant', 'CouncilDate',
#        'Discipline', 'DisciplineCount', 'Division', 'EndGrant', 'InstCity',
#        'InstCountry', 'InstPostalCode', 'InstState', 'Institution',
#        'OrganizationType', 'OriginalAmount', 'Participant', 'ParticipantCount',
#        'PrimaryDiscipline', 'Program', 'ProjectDesc', 'ProjectTitle',
#        'Supplement', 'SupplementAmount', 'SupplementCount', 'ToSupport',
#        'Unnamed: 0', 'YearAwarded'],
#       dtype='object')

# %%
# %matplotlib inline
big_frame[['Institution', 'ProjectTitle', 
           'YearAwarded','Program','AwardOutright','AwardMatching']].sort(columns=['AwardOutright'])
# Out:
# /Users/hannah/anaconda/envs/mpl/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#                                              Institution  \
# 28244                         Princeton University Press
# 27061                             University of Virginia
# 27851                   Unaffiliated Independent Scholar
# 31649         Pennsylvania State University - Brandywine
# 15179              Massachusetts Institute of Technology
# 40014                             Harvard Semitic Museum
# 49095                            Northwestern University
# 49102                           Alabama State University
# 49103                       American Antiquarian Society
# 49104              American Council of Learned Societies
# 49105                    Canterbury Shaker Village, Inc.
# 49106                     Chesapeake Bay Maritime Museum
# 49107                          Clear Lake Public Library
# 49108   Columbia College Center for Black Music Research
# 49109                  Dubuque County Historical Society
# 49110                   Encyclopaedia Iranica Foundation
# 49111                            George Mason University
# 49112                    Library Company of Philadelphia
# 49113                                      Loras College
# 49114                           Maine Humanities Council
# 49115                              Oglala Lakota College
# 49116                              Ohio State University
# 49117  Public Library of Charlotte and Mecklenburg Ce...
# 49118                              Sandwich Glass Museum
# 49119                                 Seattle Art Museum
# 49120                  Seattle Public Library Foundation
# 4445                            Rutgers University Press
# 15079         National Asian American Telecommunications
# 10178                                Library of Congress
# 4417                          Princeton University Press
# ...                                                  ...
# 46053                University of California, Riverside
# 59784                            Ohio Humanities Council
# 56497                         Florida Humanities Council
# 51854                New York Council for the Humanities
# 59062                    Pennsylvania Humanities Council
# 51862                                   Humanities Texas
# 57810                        Illinois Humanities Council
# 56589                       American Library Association
# 60463                        Illinois Humanities Council
# 61112                    Pennsylvania Humanities Council
# 46455                                Library of Virginia
# 56510                New York Council for the Humanities
# 59046                         Florida Humanities Council
# 46361                 Southeastern Library Network, Inc.
# 56518                                   Humanities Texas
# 48414                              California Humanities
# 59803                          Mid-America Arts Alliance
# 56496  State Humanities Councils General Operating Su...     5192520.00
# 59045  State Humanities Councils General Operating Su...     6113750.00
# 61094  State Humanities Councils General Operating Su...     6544450.00
#
#        AwardMatching
# 28244       11748.00
# 27061      135000.00
# 27851       16070.00
# 31649           0.00
# 15179       75000.00
# 40014           0.00
# 49095       25000.00
# 49102      500000.00
# 49103      450000.00
# 49104      500000.00
# 49105      500000.00
# 49106      500000.00
# 49107      375000.00
# 49108      122253.33
# 49109      500000.00
# 49110      500000.00
# 49111      500000.00
# 49112      500000.00
# 49113      400000.00
# 49114      250000.00
# 49115      500000.00
# 49116      416449.25
# 49117      500000.00
# 49118      440000.00
# 49119      500000.00
# 49120      500000.00
# 4445            0.00
# 15079        5067.00
# 10178       59300.00
# 4417            0.00
# ...              ...
# 46053           0.00
# 59784       64400.00
# 56497      182700.00
# 51854      200200.00
# 59062      114400.00
# 51862      221200.00
# 57810      135300.00
# 56589           0.00
# 60463       55400.00
# 61112       44100.00
# 46455           0.00
# 56510      193300.00
# 59046      159300.00
# 46361           0.00
# 56518      232500.00
# 48414      414900.00
# 59803           0.00
# 61095       63300.00
# 48470      346200.00
# 37418           0.00
# 46402           0.00
# 59066      206200.00
# 61108       63400.00
# 46406       25353.97
# 61116       82600.00
# 51840      343200.00
# 52898           0.00
# 56496      342800.00
# 59045      295900.00
# 61094      116100.00
#
# [63734 rows x 6 columns]

# %%
# %matplotlib inline

def plot_percentange(yr_state, yr):
    fig = plt.figure()

    ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.LambertConformal())
    ax.set_extent([-125, -66.5, 20, 50], ccrs.Geodetic())
    shapename = 'admin_1_states_provinces_lakes_shp'
    states_shp = shpreader.natural_earth(resolution='110m', 
                                         category='cultural', name=shapename)
    ax.background_patch.set_visible(False)
    ax.outline_patch.set_visible(False)
    states = shpreader.Reader(states_shp)

    colors = []
    patches = []


    #bounds = [1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9]
    cmap = mcm.viridis_r
    #norm = mcolors.LogNorm(vmin=bounds[0], vmax=bounds[-2])
    norm = mcolors.Normalize(vmin=0, vmax=20)
    for val,  state, geo in zip(yr_state, states.records(), states.geometries()):
        sn = state.attributes['postal']
        color = cmap(norm(((val*1.0)/yr_state.sum())*100))
        colors.append(color) # add colors to colors list
        ax.add_geometries([geo], ccrs.PlateCarree(), facecolor=color, edgecolor='black')

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm._A = []
    cb = plt.colorbar(sm, ax=ax, fraction=.035, pad=.0, aspect=15, extend='both', anchor=[-5,0])
    #, format=mticker.FormatStrFormatter('%.0f'))
    #cb.set_ticks(bounds)
    cb.ax.tick_params(labelsize=14)
    cb.set_label("% Awarded Outright", fontsize=16)
    ax.set_title("% Funded in the {}s".format(yr), fontsize=18)
    plt.show()
    fig.savefig("NEH_state_{}s".format(yr))

# %%
for df, yr in zip(dfs, [1960,1970,1980,1990,2000,2010]):
    yr_state = df.groupby('InstState')['AwardOutright'].sum()
    plot(yr_state, yr)

# %%
CUNY = big_frame[big_frame['Institution'].str.contains("CUNY Research Foundation, Graduate School and University Center")]

# %%
CUNY.to_csv("gc.csv")

# %%
CUNY['AwardOutright'].plot()

# %%
CUNY.keys()

# %%
fig, ax = plt.subplots()
CUNY.groupby('PrimaryDiscipline')['AwardOutright'].sum().plot("bar", ax=ax)
ax.set_title("CUNY by Primary Discipline")
ax.set_ylabel("Award Outright")

# %%
tab = CUNY.groupby(['BeginGrant', 'PrimaryDiscipline'])['AwardOutright'].sum().unstack()

# %%
tab.values

# %%
fig, ax = plt.subplots(figsize=(20,10))
clean_time = pd.to_datetime(tab.index.values,infer_datetime_format=True).strftime("%Y-%m")
sm = ax.imshow(tab.values.T, cmap=mcm.viridis_r)
ax.set_xticks(range(tab.index.values.shape[0]))
ax.set_xticklabels(clean_time, rotation=90)
ax.set_yticks(range(len(tab.keys())))
ax.set_yticklabels(tab.keys(),rotation=0)
cb = fig.colorbar(sm, ax=ax, fraction=.015)
cb.set_label("Award Outright ($)")

# %%
tab.keys()

# %%
pd.to_datetime(tab.index.values,infer_datetime_format=True).strftime("%Y/%m/%d")

# %%
states = dfs[-2].groupby('InstState').sum()

# %%
states[['ApprovedOutright','ApprovedMatching']].ix[['CA','KS']].sum(axis=1)/states[['ApprovedOutright','ApprovedMatching']].sum(axis=1).sum()*100

# %%
dfs[-1]

# %%
shpreader.natural_earth?

# %%
# %matplotlib inline

def plot_total(yr_state, yr):
    fig = plt.figure()

    ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.LambertConformal())
    ax.set_extent([-125, -66.5, 20, 50], ccrs.Geodetic())
    shapename = 'admin_1_states_provinces_lakes_shp'
    states_shp = shpreader.natural_earth(resolution='110m', 
                                         category='cultural', name=shapename)
    ax.background_patch.set_visible(False)
    ax.outline_patch.set_visible(False)
    states = shpreader.Reader(states_shp)

    colors = []
    patches = []


    #bounds = [1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9]
    cmap = mcm.viridis_r
    #norm = mcolors.LogNorm(vmin=bounds[0], vmax=bounds[-2])
    norm = mcolors.Normalize(vmin=0, vmax=20)
    for val,  state, geo in zip(yr_state, states.records(), states.geometries()):
        sn = state.attributes['postal']
        color = cmap(norm(((val*1.0)/yr_state.sum())*100))
        colors.append(color) # add colors to colors list
        ax.add_geometries([geo], ccrs.PlateCarree(), facecolor=color, edgecolor='black')

    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm._A = []
    cb = plt.colorbar(sm, ax=ax, fraction=.035, pad=.0, aspect=15, extend='both', anchor=[-5,0])
    #, format=mticker.FormatStrFormatter('%.0f'))
    #cb.set_ticks(bounds)
    cb.ax.tick_params(labelsize=14)
    cb.set_label("% Awarded Outright", fontsize=16)
    ax.set_title("% Funded in the {}s".format(yr), fontsize=18)
    plt.show()
    fig.savefig("NEH_state_{}s".format(yr))
